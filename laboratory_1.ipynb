# %% [markdown]
# <a href="https://colab.research.google.com/github/asmetuerr/MMO/blob/main/laboratory_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # *лабораторная работа №1. первичный анализ данных*
# ***цель работы:*** изучение программных средств для организации рабочего места специалиста по анализу данных и машинному обучению.
#
# ***порядок выполнения учебной задачи:***
#
# 1. подключение библиотеки NumPy и загрузка данных

# %%
# !wget https://raw.githubusercontent.com/asmetuerr/MMO/main/iris.data
# Out:
# --2025-02-11 18:50:18--  https://raw.githubusercontent.com/asmetuerr/MMO/main/iris.data
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4551 (4.4K) [text/plain]
# Saving to: ‘iris.data.2’
#
# iris.data.2         100%[===================>]   4.44K  --.-KB/s    in 0s
#
# 2025-02-11 18:50:18 (47.3 MB/s) - ‘iris.data.2’ saved [4551/4551]

# %%
import numpy as np
data_path = "iris.data"
data = np.genfromtxt(data_path, delimiter=",")
print(data)
# Out:
# [[5.1 3.5 1.4 0.2 nan]
#  [4.9 3.  1.4 0.2 nan]
#  [4.7 3.2 1.3 0.2 nan]
#  [4.6 3.1 1.5 0.2 nan]
#  [5.  3.6 1.4 0.2 nan]
#  [5.4 3.9 1.7 0.4 nan]
#  [4.6 3.4 1.4 0.3 nan]
#  [5.  3.4 1.5 0.2 nan]
#  [4.4 2.9 1.4 0.2 nan]
#  [4.9 3.1 1.5 0.1 nan]
#  [5.4 3.7 1.5 0.2 nan]
#  [4.8 3.4 1.6 0.2 nan]
#  [4.8 3.  1.4 0.1 nan]
#  [4.3 3.  1.1 0.1 nan]
#  [5.8 4.  1.2 0.2 nan]
#  [5.7 4.4 1.5 0.4 nan]
#  [5.4 3.9 1.3 0.4 nan]
#  [5.1 3.5 1.4 0.3 nan]
#  [5.7 3.8 1.7 0.3 nan]
#  [5.1 3.8 1.5 0.3 nan]
#  [5.4 3.4 1.7 0.2 nan]
#  [5.1 3.7 1.5 0.4 nan]
#  [4.6 3.6 1.  0.2 nan]
#  [5.1 3.3 1.7 0.5 nan]
#  [4.8 3.4 1.9 0.2 nan]
#  [5.  3.  1.6 0.2 nan]
#  [5.  3.4 1.6 0.4 nan]
#  [5.2 3.5 1.5 0.2 nan]
#  [5.2 3.4 1.4 0.2 nan]
#  [4.7 3.2 1.6 0.2 nan]
#  [4.8 3.1 1.6 0.2 nan]
#  [5.4 3.4 1.5 0.4 nan]
#  [5.2 4.1 1.5 0.1 nan]
#  [5.5 4.2 1.4 0.2 nan]
#  [4.9 3.1 1.5 0.1 nan]
#  [5.  3.2 1.2 0.2 nan]
#  [5.5 3.5 1.3 0.2 nan]
#  [4.9 3.1 1.5 0.1 nan]
#  [4.4 3.  1.3 0.2 nan]
#  [5.1 3.4 1.5 0.2 nan]
# ...

# %% [markdown]
# **тип переменной и форма (shape)**

# %%
print ( "Data type : ", type(data) )
print ( "Data shape : ", data.shape )
print ( data[-4:] )
# Out:
# Data type :  <class 'numpy.ndarray'>
# Data shape :  (150, 5)
# [[6.3 2.5 5.  1.9 nan]
#  [6.5 3.  5.2 2.  nan]
#  [6.2 3.4 5.4 2.3 nan]
#  [5.9 3.  5.1 1.8 nan]]

# %% [markdown]
# **получение типа набора данных, строки, элемента**

# %%
data1 = np.genfromtxt(data_path, delimiter=",", dtype=None)
print('Shape of the dataset:', data1.shape)
print('Dataset type:', type(data1))
print('A single row of the dataset is type of:', type(data1[0]))
print('Types of elements:', type(data1[0][1]), type(data1[0][4]))
print('Dataset:')
print(data1)
# Out:
# Shape of the dataset: (150,)
# Dataset type: <class 'numpy.ndarray'>
# A single row of the dataset is type of: <class 'numpy.void'>
# Types of elements: <class 'numpy.float64'> <class 'numpy.bytes_'>
# Dataset:
# [(5.1, 3.5, 1.4, 0.2, b'Iris-setosa') (4.9, 3. , 1.4, 0.2, b'Iris-setosa')
#  (4.7, 3.2, 1.3, 0.2, b'Iris-setosa') (4.6, 3.1, 1.5, 0.2, b'Iris-setosa')
#  (5. , 3.6, 1.4, 0.2, b'Iris-setosa') (5.4, 3.9, 1.7, 0.4, b'Iris-setosa')
#  (4.6, 3.4, 1.4, 0.3, b'Iris-setosa') (5. , 3.4, 1.5, 0.2, b'Iris-setosa')
#  (4.4, 2.9, 1.4, 0.2, b'Iris-setosa') (4.9, 3.1, 1.5, 0.1, b'Iris-setosa')
#  (5.4, 3.7, 1.5, 0.2, b'Iris-setosa') (4.8, 3.4, 1.6, 0.2, b'Iris-setosa')
#  (4.8, 3. , 1.4, 0.1, b'Iris-setosa') (4.3, 3. , 1.1, 0.1, b'Iris-setosa')
#  (5.8, 4. , 1.2, 0.2, b'Iris-setosa') (5.7, 4.4, 1.5, 0.4, b'Iris-setosa')
#  (5.4, 3.9, 1.3, 0.4, b'Iris-setosa') (5.1, 3.5, 1.4, 0.3, b'Iris-setosa')
#  (5.7, 3.8, 1.7, 0.3, b'Iris-setosa') (5.1, 3.8, 1.5, 0.3, b'Iris-setosa')
# ...

# %% [markdown]
# **указание типа столбцов при загрузке данных**

# %%
dt = np.dtype("f8, f8, f8, f8, U30")
data2 = np.genfromtxt(data_path, delimiter=",", dtype=dt)
print('Shape of the dataset:', data2.shape)
print('Dataset type:', type(data2))
print('A single row of the dataset is type of:', type(data2[0]))
print('Types of elements:', type(data2[0][1]), type(data2[0][4]))
print('Dataset slice:')
print(data2[:10])
# Out:
# Shape of the dataset: (150,)
# Dataset type: <class 'numpy.ndarray'>
# A single row of the dataset is type of: <class 'numpy.void'>
# Types of elements: <class 'numpy.float64'> <class 'numpy.str_'>
# Dataset slice:
# [(5.1, 3.5, 1.4, 0.2, 'Iris-setosa') (4.9, 3. , 1.4, 0.2, 'Iris-setosa')
#  (4.7, 3.2, 1.3, 0.2, 'Iris-setosa') (4.6, 3.1, 1.5, 0.2, 'Iris-setosa')
#  (5. , 3.6, 1.4, 0.2, 'Iris-setosa') (5.4, 3.9, 1.7, 0.4, 'Iris-setosa')
#  (4.6, 3.4, 1.4, 0.3, 'Iris-setosa') (5. , 3.4, 1.5, 0.2, 'Iris-setosa')
#  (4.4, 2.9, 1.4, 0.2, 'Iris-setosa') (4.9, 3.1, 1.5, 0.1, 'Iris-setosa')]

# %% [markdown]
# **построение графиков с использованием Matplotlib**

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# Данные из отдельных столбцов
sepal_length = [] # Sepal Length
sepal_width = [] # Sepal Width
petal_length = [] # Petal Length
petal_width = [] # Petal Width

# Выполняем обход всей коллекции data2
for dot in data2:
    sepal_length.append(dot[0])
    sepal_width.append(dot[1])
    petal_length.append(dot[2])
    petal_width.append(dot[3])

# Строим графики по проекциям данных
# Учитываем, что каждые 50 типов ирисов идут последовательно
plt.figure(1)
setosa, = plt.plot(sepal_length[:50], sepal_width[:50], 'ro', label='Setosa')
versicolor, = plt.plot(sepal_length[50:100], sepal_width[50:100], 'g^', label='Versicolor')
virginica, = plt.plot(sepal_length[100:150], sepal_width[100:150], 'bs', label='Verginica')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')

plt.figure(2)
setosa, = plt.plot(sepal_length[:50], petal_length[:50], 'ro', label='Setosa')
versicolor, = plt.plot(sepal_length[50:100], petal_length[50:100], 'g^', label='Versicolor')
virginica, = plt.plot(sepal_length[100:150], petal_length[100:150], 'bs', label='Verginica')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')

plt.figure(3)
setosa, = plt.plot(sepal_length[:50], petal_width[:50], 'ro', label='Setosa')
versicolor, = plt.plot(sepal_length[50:100], petal_width[50:100], 'g^', label='Versicolor')
virginica, = plt.plot(sepal_length[100:150], petal_width[100:150], 'bs', label='Verginica')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('Sepal Length')
plt.ylabel('Petal Width')

plt.show()

# %% [markdown]
# набор датасета "Wine". данный набор предназначен для построения модели классификации. данные о 178 экземплярах вина являются результатами химического анализа вин, выращенных в одном регионе Италии, но изи трех разных сортов. в ходе анализа были определены 13 компонентов, содержащихся в каждом из трех сортов вин.
# на основании этого набора данных требуется построить правило классификации, определяющее сортв вина по данным анализа.
#
# # **порядок выполнения индивидуального задания:**
#
#
# 1. подключение библиотеки NumPy и загрузка данных

# %%
# !wget https://raw.githubusercontent.com/asmetuerr/MMO/main/wine.data
# Out:
# --2025-02-11 18:45:39--  https://raw.githubusercontent.com/asmetuerr/MMO/main/wine.data
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10782 (11K) [text/plain]
# Saving to: ‘wine.data.1’
#
# wine.data.1         100%[===================>]  10.53K  --.-KB/s    in 0s
#
# 2025-02-11 18:45:39 (82.2 MB/s) - ‘wine.data.1’ saved [10782/10782]

# %%
import numpy as np
data = np.genfromtxt("wine.data", delimiter=",")
print(data)
# Out:
# [[1.000e+00 1.423e+01 1.710e+00 ... 1.040e+00 3.920e+00 1.065e+03]
#  [1.000e+00 1.320e+01 1.780e+00 ... 1.050e+00 3.400e+00 1.050e+03]
#  [1.000e+00 1.316e+01 2.360e+00 ... 1.030e+00 3.170e+00 1.185e+03]
#  ...
#  [3.000e+00 1.327e+01 4.280e+00 ... 5.900e-01 1.560e+00 8.350e+02]
#  [3.000e+00 1.317e+01 2.590e+00 ... 6.000e-01 1.620e+00 8.400e+02]
#  [3.000e+00 1.413e+01 4.100e+00 ... 6.100e-01 1.600e+00 5.600e+02]]

# %% [markdown]
# **тип переменной и форма (shape)**

# %%
print ( "Data type : ", type(data) )
print ( "Data shape : ", data.shape )
print (data[-4:])
# Out:
# Data type :  <class 'numpy.ndarray'>
# Data shape :  (178, 14)
# [[3.000e+00 1.340e+01 3.910e+00 2.480e+00 2.300e+01 1.020e+02 1.800e+00
#   7.500e-01 4.300e-01 1.410e+00 7.300e+00 7.000e-01 1.560e+00 7.500e+02]
#  [3.000e+00 1.327e+01 4.280e+00 2.260e+00 2.000e+01 1.200e+02 1.590e+00
#   6.900e-01 4.300e-01 1.350e+00 1.020e+01 5.900e-01 1.560e+00 8.350e+02]
#  [3.000e+00 1.317e+01 2.590e+00 2.370e+00 2.000e+01 1.200e+02 1.650e+00
#   6.800e-01 5.300e-01 1.460e+00 9.300e+00 6.000e-01 1.620e+00 8.400e+02]
#  [3.000e+00 1.413e+01 4.100e+00 2.740e+00 2.450e+01 9.600e+01 2.050e+00
#   7.600e-01 5.600e-01 1.350e+00 9.200e+00 6.100e-01 1.600e+00 5.600e+02]]

# %% [markdown]
# **получение типа набора данных, строки, элемента**

# %%
data1 = np.genfromtxt('wine.data', delimiter=",", dtype=None)
print('Shape of the dataset:', data1.shape)
print('Dataset type:', type(data1))
print('A single row of the dataset is type of:', type(data1[0]))
print('Types of elements:', type(data1[0][0]), type(data1[0][10]))
print('Dataset:')
print(data1)
# Out:
# Shape of the dataset: (178,)
# Dataset type: <class 'numpy.ndarray'>
# A single row of the dataset is type of: <class 'numpy.void'>
# Types of elements: <class 'numpy.int64'> <class 'numpy.float64'>
# Dataset:
# [(1, 14.23, 1.71, 2.43, 15.6, 127, 2.8 , 3.06, 0.28, 2.29,  5.64    , 1.04 , 3.92, 1065)
#  (1, 13.2 , 1.78, 2.14, 11.2, 100, 2.65, 2.76, 0.26, 1.28,  4.38    , 1.05 , 3.4 , 1050)
#  (1, 13.16, 2.36, 2.67, 18.6, 101, 2.8 , 3.24, 0.3 , 2.81,  5.68    , 1.03 , 3.17, 1185)
#  (1, 14.37, 1.95, 2.5 , 16.8, 113, 3.85, 3.49, 0.24, 2.18,  7.8     , 0.86 , 3.45, 1480)
#  (1, 13.24, 2.59, 2.87, 21. , 118, 2.8 , 2.69, 0.39, 1.82,  4.32    , 1.04 , 2.93,  735)
#  (1, 14.2 , 1.76, 2.45, 15.2, 112, 3.27, 3.39, 0.34, 1.97,  6.75    , 1.05 , 2.85, 1450)
#  (1, 14.39, 1.87, 2.45, 14.6,  96, 2.5 , 2.52, 0.3 , 1.98,  5.25    , 1.02 , 3.58, 1290)
#  (1, 14.06, 2.15, 2.61, 17.6, 121, 2.6 , 2.51, 0.31, 1.25,  5.05    , 1.06 , 3.58, 1295)
# ...

# %% [markdown]
# **указание типа столбцов при загрузке данных**

# %%
dt = np.dtype("f2")
data2 = np.genfromtxt('wine.data', delimiter=",", dtype=dt)
print('Shape of the dataset:', data2.shape)
print('Dataset type:', type(data2))
print('A single row of the dataset is type of:', type(data2[0]))
print('Types of elements:', type(data2[0][1]), type(data2[0][4]))
print('Dataset slice:')
print(data2[:10])
# Out:
# Shape of the dataset: (178, 14)
# Dataset type: <class 'numpy.ndarray'>
# A single row of the dataset is type of: <class 'numpy.ndarray'>
# Types of elements: <class 'numpy.float16'> <class 'numpy.float16'>
# Dataset slice:
# [[1.000e+00 1.423e+01 1.710e+00 2.430e+00 1.560e+01 1.270e+02 2.801e+00
#   3.061e+00 2.800e-01 2.289e+00 5.641e+00 1.040e+00 3.920e+00 1.065e+03]
#  [1.000e+00 1.320e+01 1.780e+00 2.141e+00 1.120e+01 1.000e+02 2.650e+00
#   2.760e+00 2.600e-01 1.280e+00 4.379e+00 1.050e+00 3.400e+00 1.050e+03]
#  [1.000e+00 1.316e+01 2.359e+00 2.670e+00 1.859e+01 1.010e+02 2.801e+00
#   3.240e+00 3.000e-01 2.811e+00 5.680e+00 1.030e+00 3.170e+00 1.185e+03]
#  [1.000e+00 1.437e+01 1.950e+00 2.500e+00 1.680e+01 1.130e+02 3.850e+00
#   3.490e+00 2.400e-01 2.180e+00 7.801e+00 8.599e-01 3.449e+00 1.480e+03]
#  [1.000e+00 1.324e+01 2.590e+00 2.869e+00 2.100e+01 1.180e+02 2.801e+00
#   2.689e+00 3.899e-01 1.820e+00 4.320e+00 1.040e+00 2.930e+00 7.350e+02]
# ...

# %% [markdown]
# **построение графиков с использованием Matplotlib**

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

alcohol = []
malicaid = []
ash = []
alcalinity_of_ash = []
magnesium = []
total_phenols = []
flavanoids = []
nonflavanoid_phenols = []
proanthocyanins = []
color_intensity = []
hue = []
D280_0D315_of_diluted_wines = []
proline = []

for dot in data2:
  alcohol.append(dot[1])
  malicaid.append(dot[2])
  ash.append(dot[3])
  alcalinity_of_ash.append(dot[4])
  magnesium.append(dot[5])
  total_phenols.append(dot[6])
  flavanoids.append(dot[7])
  nonflavanoid_phenols.append(dot[8])
  proanthocyanins.append(dot[9])
  color_intensity.append(dot[10])
  hue.append(dot[11])
  D280_0D315_of_diluted_wines.append(dot[12])
  proline.append(dot[13])

plt.figure(1)
first, = plt.plot(alcohol[:59], proline[:59], 'ro', label='First')
second, = plt.plot(alcohol[59:71], proline[59:71], 'g^', label='Second')
third, = plt.plot(alcohol[71:178], proline[71:178], 'bs', label='Third')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('alcohol')
plt.ylabel('proline')

plt.figure(2)
first, = plt.plot(alcohol[:59], D280_0D315_of_diluted_wines[:59], 'ro', label='First')
second, = plt.plot(alcohol[59:71], D280_0D315_of_diluted_wines[59:71], 'g^', label='Second')
third, = plt.plot(alcohol[71:178], D280_0D315_of_diluted_wines[71:178], 'bs', label='Third')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('alcohol')
plt.ylabel('D280_0D315_of_diluted_wines')

plt.figure(3)
first, = plt.plot(proline[:59], malicaid[:59], 'ro', label='First')
second, = plt.plot(proline[59:71], malicaid[59:71], 'g^', label='Second')
third, = plt.plot(proline[71:178], malicaid[71:178], 'bs', label='Third')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('proline')
plt.ylabel('malicaid')

plt.figure(4)
first, = plt.plot(D280_0D315_of_diluted_wines[:59], proline[:59], 'ro', label='First')
second, = plt.plot(D280_0D315_of_diluted_wines[59:71], proline[59:71], 'g^', label='Second')
third, = plt.plot(D280_0D315_of_diluted_wines[71:178], proline[71:178], 'bs', label='Third')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('D280_0D315_of_diluted_wines')
plt.ylabel('proline')

plt.show()

# %% [markdown]
# из графиков видно, что множество first достаточно хорошо отделимо, а множества second и third представляют собой множества, разделение которых является непростой задачей.
#
# ***ответы на контрольные вопросы:***
#
# 1. Некоторые инструментальные средства, которые используются для организации рабочего места специалиста по Data Science:
#
# Jupyter Notebook. Инструмент для проведения исследовательской работы в сфере науки о данных. Позволяет писать код, загружать и визуализировать данные, добавлять поясняющие комментарии, формулы, таблицы.
# PyCharm. Интегрированная среда разработки (IDE) для Python. Поддерживает автодополнение кода, отладку, рефакторинг и интеграцию с системами контроля версий.
# Git. Система контроля версий.
# GitLab. Инструмент для управления жизненным циклом кода.
# DVC. Инструмент версионирования данных, который помогает не только версионировать датасеты, но и автоматизировать пайплайны обработки данных и управлять проведением экспериментов.
# Инструменты для управления экспериментами. Позволяют хранить результаты экспериментов и сравнивать их. Примеры таких решений — MLflow, ClearML, Weights & Biases и другие.
# Облачные решения для работы с данными. Например, Google Cloud Platform, Colab и Drive позволяют делать удалённые вычисления и экспериментировать в ноутбуках.
#
# 2. Библиотеки Python, которые используются в области машинного обучения:
#
# Pandas. Фундаментальная библиотека для обработки и анализа данных. Позволяет легко импортировать, очищать, трансформировать и анализировать данные. 4
# NumPy. Предоставляет мощные инструменты для работы с многомерными массивами и матрицами. Это основа для многих алгоритмов МО, обеспечивая высокую производительность вычислений.
# SciPy. Расширяет возможности NumPy, добавляя продвинутые математические функции, такие как оптимизация, интерполяция и статистика.
# TensorFlow. Библиотека для построения, обучения и развёртывания сложных моделей машинного обучения. Подходит для работы с большими массивами данных и сложными архитектурами нейронных сетей.
# Keras. Библиотека для разработки и оценки нейронных сетей в рамках моделей машинного обучения и глубокого обучения.
# PyTorch. Библиотека для динамического глубокого обучения и исследовательских приложений. Известна своим динамическим вычислительным графом, который строит графы «на лету».
#
# 3. Библиотеки Python получили широкое распространение при реализации систем машинного обучения благодаря простому синтаксису языка, большому выбору библиотек и фреймворков, а также кросс-платформенности.
